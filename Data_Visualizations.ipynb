# %% [markdown]
# ## Dataset Visualizations

# %%
import urllib
import pandas as pd
import numpy as np

# %%
from data_visuals_class import graph_visuals
# import py file

# %%
msd = pd.read_csv('msd_cleaned.csv')
msd
# Out:
#       SongNumber              SongID  AlbumID  \
# 0              1  SOMZWCG12A8C13C480   300848
# 1              2  SOCIWDW12A8C13D406   300822
# 2              3  SOXVLOJ12AB0189215   514953
# 3              4  SONHOTT12A8C13493C   287650
# 4              5  SOFSOCN12A8C143F5D   611336
# ...          ...                 ...      ...
# 9167        9996  SOLXXPY12A67ADABA0   691752
# 9168        9997  SOAYONI12A6D4F85C8    41649
# 9169        9998  SOJZLAJ12AB017E8A2   346402
# 9170        9999  SORZSCJ12A8C132446    86259
# 9171       10000  SOFAOMI12A6D4FA2D8    64501
#
#                                 AlbumName            ArtistID  \
# 0                             Fear Itself  ARD7TVE1187B99BFB1
# 1                              Dimensions  ARMJAGH1187FB546F3
# 2     Las Numero 1 De La Sonora Santanera  ARKRRTF1187B9984DA
# 3                           Friend Or Foe  AR7G5I41187FB4CE6C
# 4                           Muertos Vivos  ARXR32B1187FB57099
# ...

# %% [markdown]
# ### Determining Graph Titles

# %%
# assign appropraite strings with axis titles to variables
Duration = 'Duration (seconds)'
Tempo = 'Tempo (BPM, Beats Per Minute)'
AlbumName = 'Album Title'
Danceability = 'Danceability Measure of Song'
KeySignature = 'Estimation of the Key from the Song'
TimeSignature = 'Time signature, Number of Beats Per Bar'
Title = 'Song Title'
Year = 'Year of Song Release'
SongHotness = 'Hotness of Song When Downloaded'

# %% [markdown]
# ### Scatterplots

# %% [markdown]
# **Duration vs. Tempo**

# %%
# drops any rows where Duration or Tempo is 0, cleans up data
msd_drop_dur = msd.loc[msd['Duration'] > 0]
msd_drop_durtemp = msd_drop_dur.loc[msd_drop_dur['Tempo'] > 0]

duration_tempo = graph_visuals(msd_drop_durtemp['Duration'], Duration, msd_drop_durtemp['Tempo'], Tempo)
duration_tempo.scatter_plot()

# name = graph_visuals(df['columnname1'], x-axis-title, df['columnname2'], y-axis-title)
# name.scatter_plot()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# **Tempo vs. Time Signature**

# %%
tempo_timesignature = graph_visuals(msd['Tempo'], Tempo, msd['TimeSignature'], TimeSignature)
tempo_timesignature.scatter_plot()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# **Duration vs. Time Signature**

# %%
# drops any rows where the seconds for Duration is longer than 700, better for viewing patterns
msd_drop_dur = msd.loc[msd['Duration'] < 700]

duration_timesignature = graph_visuals(msd_drop_dur['Duration'], Duration,msd_drop_dur['TimeSignature'], TimeSignature)
duration_timesignature.scatter_plot()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# **Duration vs. Song Hotness**

# %%
# drops any rows that have songHotness as 0
msd_droppedHot = msd.loc[msd["SongHotness"] > 0 ]

duration_songhotness = graph_visuals(msd_droppedHot['Duration'], Duration, msd_droppedHot['SongHotness'], SongHotness)
duration_songhotness.scatter_plot()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# ### Frequency Bar Graphs and Histograms

# %% [markdown]
# **Frequency Bar Graph, Year**

# %%
# Drops rows where the value for Year is 0
msd_drop_year = msd.loc[msd["Year"] > 0 ]

year_data = graph_visuals(msd_drop_year['Year'],  Year)
year_data.frequency_bar_graph()

# %% [markdown]
# **Histogram, Tempo**

# %%
# drops rows where the value of Tempo is 0
msd_drop_tempo = msd.loc[msd["Tempo"] > 0 ]

tempo_data = graph_visuals(msd_drop_tempo['Tempo'], Tempo, bins = 20)
tempo_data.hist_graph()
